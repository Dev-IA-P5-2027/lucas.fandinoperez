# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import imutils

# %%
img = cv2.imread("toucan.jpg", 3)
print(img.shape)
# Out:
# (853, 1280, 3)

# %%
cv2.imshow("Image_toucan", img)

k = cv2.waitKey(5000)

# %%
cv2.imwrite("toucan_png.png", img)
# Out:
# True

# %%
img2 = cv2.imread("toucan_png.png", 0)
cv2.imshow("Toucan_gris", img2)
k = cv2.waitKey(5000)
